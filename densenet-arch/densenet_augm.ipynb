# %%
#---------- IMPORTS -----------

#Simple Imports
import cv2
import os
import pickle
import numpy as np
import tensorflow as tf
import random
import datetime
import glob
import seaborn as sns

#Tensorflow/Keras Imports
import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam

#Aux Imports
import matplotlib.pyplot as plt
from IPython.display import  display
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tqdm import tqdm
from sklearn.metrics import confusion_matrix,roc_curve, auc, precision_recall_curve

# %% [markdown]
# ## Model Creator

# %%
#Creacion del modelo preentrenado en CNN

def build_model(pretrained):
    #Sequential - Las capas internas se apilan de manera vertical
    model = Sequential([
        #Pretrained - La construccion del modelo es preentrenado
        pretrained,
        #GlobalAveragePooling2D - Las capas se comunicaran de manera binaria
        layers.GlobalAveragePooling2D(),
        #sigmoid - La salida será binaria
        layers.Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        #binary_crossentropy - Mas adecuado para la clasificacion binaria
        loss='binary_crossentropy',
        #Adam - Version avanzada de SGD
        optimizer=Adam(),
        #accuracy - Metrica a tener en cuenta
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# # Model Generator

# %%
#Ruta de nuestro dataset
base_path = '../dataset/real-vs-fake/'
real_path = '../dataset/real-vs-fake/test/real'
fake_path = '../dataset/real-vs-fake/test/fake'

#Conjuntos de Imagenes
real_images = [os.path.join(real_path, img) for img in os.listdir(real_path)]
fake_images = [os.path.join(fake_path, img) for img in os.listdir(fake_path)]

# %%
#Pick de fotos de entreno

#Normalizamos los valores de los pixeles, dividimos /255 para obtener los valores de RGB entre 0 y 1 y rotamos las fotos
image_gen = ImageDataGenerator(rescale=1./255.,
                               rotation_range=20,
                               horizontal_flip=True)

train_flow = image_gen.flow_from_directory(
    base_path + 'train/',
    #Redimension de las imagenes
    target_size=(224, 224),
    #Tamaño de lote
    batch_size=64,
    #Modo de clasificacion, 1 y 0
    class_mode='binary'
)

print("Train subfolders: ", os.listdir(base_path + 'train/'))
# Out:
# Found 50000 images belonging to 2 classes.
# Train subfolders:  ['fake', 'real']

# %%
#Pick de fotos de validacion
image_gen1 = ImageDataGenerator(rescale=1./255.,
                               rotation_range=20,
                               horizontal_flip=True)
valid_flow = image_gen1.flow_from_directory(
    base_path + 'valid/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

print("Train subfolders: ", os.listdir(base_path + 'valid/'))
# Out:
# Found 5000 images belonging to 2 classes.
# Train subfolders:  ['fake', 'real']

# %% [markdown]
# # Short EDA - Exploratory Data Analysis

# %%
images_df = {
    "folder":[],
    "image_path":[],
    "label":[]
}

for folder in os.listdir(base_path): 
    for label in os.listdir(base_path + "/" + folder):
        for img in glob.glob(base_path + "/" + folder + "/" + label + "/*.jpg"):
            images_df["folder"].append(folder)
            images_df["image_path"].append(img)
            images_df["label"].append(label)

# %%
images_df = pd.DataFrame(images_df)

# %%
images_df
# Out:
#       folder                                         image_path label
# 0       test  ../dataset/real-vs-fake//test/fake\QS994V4M2T.jpg  fake
# 1       test  ../dataset/real-vs-fake//test/fake\QSB3LIBHML.jpg  fake
# 2       test  ../dataset/real-vs-fake//test/fake\QSE7B3Z850.jpg  fake
# 3       test  ../dataset/real-vs-fake//test/fake\QSFUPGKK87.jpg  fake
# 4       test  ../dataset/real-vs-fake//test/fake\QSIGUG4X1W.jpg  fake
# ...      ...                                                ...   ...
# 59995  valid      ../dataset/real-vs-fake//valid/real\69960.jpg  real
# 59996  valid      ../dataset/real-vs-fake//valid/real\69963.jpg  real
# 59997  valid      ../dataset/real-vs-fake//valid/real\69987.jpg  real
# 59998  valid      ../dataset/real-vs-fake//valid/real\69996.jpg  real
# 59999  valid      ../dataset/real-vs-fake//valid/real\69997.jpg  real
#
# [60000 rows x 3 columns]

# %% [markdown]
# ### Labels Distribution

# %%
real_grouped_df = images_df[images_df['label'] == "real"].groupby('folder')
fake_grouped_df = images_df[images_df['label'] == "fake"].groupby('folder')

# %%
real_grouped_df.size()
# Out:
# folder
# test      2500
# train    25000
# valid     2500
# dtype: int64

# %%
fake_grouped_df.size()
# Out:
# folder
# test      2500
# train    25000
# valid     2500
# dtype: int64

# %%
def plot_images(img, label):
    plt.figure(figsize=[12, 12])
    for i in range(16):
        plt.subplot(4, 4, i+1)
        plt.imshow(img[i])
        plt.axis('off')
        if label[i] == 0:
            plt.title("Fake")
        else:
            plt.title("Real")

# %%
img,lbl = next(train_flow)
plot_images(img,lbl)

# %%
for img, label in train_flow:
    print("Values: ", img[0])
    print("Label: ", label[0])
    break
# Out:
# Values:  [[[0.15294118 0.19215688 0.23137257]
#   [0.15294118 0.19215688 0.23137257]
#   [0.15932885 0.19854453 0.23776022]
#   ...
#   [0.15294118 0.20784315 0.25882354]
#   [0.14611867 0.20784315 0.25882354]
#   [0.14509805 0.20784315 0.25882354]]
#
#  [[0.15294118 0.19215688 0.23137257]
#   [0.15294118 0.19215688 0.23137257]
#   [0.155921   0.1951367  0.23435238]
#   ...
#   [0.15636218 0.21126413 0.26224452]
#   [0.14952594 0.21125956 0.26223996]
#   [0.1485099  0.211255   0.26223537]]
#
#  [[0.15243086 0.19164656 0.23086224]
#   [0.15243545 0.19165114 0.23086682]
#   [0.15287721 0.19209291 0.2313086 ]
#   ...
#   [0.15686275 0.21176472 0.2627451 ]
#   [0.15598156 0.21176472 0.2627451 ]
#   [0.1558433  0.21176472 0.2627451 ]]
#
#  ...
#
#  [[0.5123297  0.55546695 0.66527086]
#   [0.47858036 0.52084446 0.6310849 ]
#   [0.49122784 0.5273952  0.6406841 ]
#   ...
#   [0.19320059 0.25302643 0.33200037]
#   [0.18672326 0.24655826 0.3204229 ]
#   [0.18329312 0.24313727 0.32293868]]
#
#  [[0.5137326  0.5568699  0.66667384]
#   [0.48638824 0.5295255  0.63932943]
#   [0.4810608  0.52318656 0.6334962 ]
#   ...
#   [0.2805783  0.3394018  0.42758524]
#   [0.27268592 0.33150944 0.41386122]
#   [0.26618388 0.3250074  0.4141829 ]]
#
#  [[0.5145852  0.55772245 0.6675264 ]
#   [0.4905455  0.53368276 0.6434867 ]
#   [0.4722801  0.5143967  0.624711  ]
#   ...
#   [0.36150625 0.42032978 0.5103956 ]
#   [0.35357162 0.41239515 0.50171125]
#   [0.34665647 0.40548    0.49567607]]]
# Label:  1.0

# %%
for img, label in train_flow:
    print(img.shape)
    print(label.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)

# %% [markdown]
# # Train Model DenseNet

# %%
#Creacion de modelo DenseNet121

#Modelo preentrenado de 121 capas
densenet = DenseNet121(
    #No utilizamos pesos
    weights=None,
    #No utilizamos fully_connected
    include_top=False,
    #Forma de entrada de las imagenes
    input_shape=(224,224,3)
)
#Construccion de modelo secuencial e impresion de informacion
model = build_model(densenet)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ ?                      │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,037,504 (26.85 MB)
#  Trainable params: 6,953,856 (26.53 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
#Entrenamos el Modelo

#Dividimos las entradas por el numero de batch
train_steps = 100000//64
valid_steps = 20000//64

#Guardamos el historico
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


history = model.fit(
    train_flow,
    epochs = 10,
    steps_per_epoch =train_steps,
    validation_data =valid_flow,
    validation_steps = valid_steps,
    callbacks=[tensorboard_callback]
)

with open('history.pickle', 'wb') as file:
    pickle.dump(history.history, file)
# Out:
# Epoch 1/10
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  782/1562 ━━━━━━━━━━━━━━━━━━━━ 2:36:56 12s/step - accuracy: 0.6042 - loss: 0.6705
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 9710s 6s/step - accuracy: 0.6261 - loss: 0.6486 - val_accuracy: 0.5476 - val_loss: 1.2767
# Epoch 2/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8748s 6s/step - accuracy: 0.7527 - loss: 0.5093 - val_accuracy: 0.6020 - val_loss: 1.0245
# Epoch 3/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8473s 5s/step - accuracy: 0.8187 - loss: 0.4012 - val_accuracy: 0.5844 - val_loss: 1.0543
# Epoch 4/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8342s 5s/step - accuracy: 0.8697 - loss: 0.3047 - val_accuracy: 0.8316 - val_loss: 0.4099
# Epoch 5/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8389s 5s/step - accuracy: 0.9103 - loss: 0.2243 - val_accuracy: 0.7596 - val_loss: 0.6969
# Epoch 6/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8492s 5s/step - accuracy: 0.9335 - loss: 0.1687 - val_accuracy: 0.7758 - val_loss: 0.6322
# Epoch 7/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8687s 6s/step - accuracy: 0.9504 - loss: 0.1258 - val_accuracy: 0.9012 - val_loss: 0.2462
# Epoch 8/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8629s 6s/step - accuracy: 0.9626 - loss: 0.0970 - val_accuracy: 0.9074 - val_loss: 0.2370
# Epoch 9/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8541s 5s/step - accuracy: 0.9709 - loss: 0.0767 - val_accuracy: 0.8616 - val_loss: 0.4394
# Epoch 10/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8613s 6s/step - accuracy: 0.9770 - loss: 0.0604 - val_accuracy: 0.9318 - val_loss: 0.2001

# %% [markdown]
# # Evaluation

# %%
#Guardamos el modelo
tf.saved_model.save(model, '../models/densent-augm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Guardamos el modelo
# ----> 2 tf.saved_model.save(model, '../models/densent-augm')
#
# NameError: name 'model' is not defined

# %%
#Cargamos el modelo y obtenemos la funcion de inferencia
model_dir = '../models/densent-augm'
model = tf.saved_model.load(model_dir)
inference_func = model.signatures["serving_default"]
print(inference_func)
# Out:
# ConcreteFunction Input Parameters:
#   inputs (KEYWORD_ONLY): TensorSpec(shape=(None, 224, 224, 1), dtype=tf.float32, name='inputs')
# Output Type:
#   Dict[['output_0', TensorSpec(shape=(None, 1), dtype=tf.float32, name='output_0')]]
# Captures:
#   2376210580224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210580048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210579872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210579696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210579520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210628304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071318864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071318688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210628128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071318160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210627072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071315872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210626016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210625840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210625664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071322208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071322384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210625488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210625312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210625136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071322912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210624080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071324320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071324496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210623024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210622848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210622672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210622496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210622320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210622144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071327488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071327664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071330128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071327840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210620032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210619856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071331008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071331360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210619680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210619504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210619328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210484384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210484208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210619152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210483328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210483152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210618096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210481920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210481744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210481568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210481392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210617040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210616512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210616336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210595008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210594832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210616160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210594656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210594480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210615104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210614048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210612640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210612464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210591840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210591488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210613872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210613696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210613520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210613344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210613168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210612992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071167696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071167520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071167344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210588848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071167168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210588672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210588496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071166112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210585680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210585504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071165056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071163472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071163296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071164000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071163120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210583040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210582864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210582688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210582512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071160480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210582336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210582160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071161008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071160832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210585856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210585328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210585152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210584976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210581104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071159072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210580928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210580752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210580576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210580400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071158016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071157840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071157664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071157488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210621440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071157312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071157136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210616864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210616688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210612816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210612288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071156080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071163824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071163648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071160304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071160128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071154848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071154672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071154496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071155376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071154320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071380512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071380336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071154144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071153088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071151856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071367840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071367664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071380688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302116208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302116032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071152032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071380160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071151680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071379104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302102832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302100720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302100544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071378048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051244576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051244400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071377696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071377520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051244224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051244048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071377344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071377168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051243872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051243696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071376464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051243520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071375056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071374000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071373824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071373472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071373296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071373120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071372064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071371008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051239648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051239472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071370656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071370480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051239296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051239120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071370304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071370128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051238592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051238064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071321680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071321504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071321152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071368016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071369424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071367488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071367136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071319392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071318512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071318336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071366080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071317104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071365024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071316224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071364848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071364672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302116560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071315696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071315520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302116384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302102656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071322560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071322736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302115680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302115504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302115328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302115152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071323968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071324144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071324672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071324848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302114096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071325552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302113040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302112864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071326960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302112688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302112512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071327136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071327312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302112160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051243168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051242992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071328896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071329424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302111104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071330304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071330480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071330656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071330832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302110048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302109872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302109696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210483856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210484032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302109520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302109344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302109168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210483680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210483504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302108112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210482096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051241056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051240880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210481216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210595536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302107056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210595360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210595184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210594304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210594128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302106000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210593776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302105824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302105648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302105472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302105296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302105120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210592368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210591664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302104064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210591136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210590960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302103184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051238944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376051238768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210589200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071321856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302102480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302102304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210588320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210588144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302102128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071321328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210587792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302101248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210586736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376071320800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376302100896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210484736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2376210484560: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
def plot_loss(epochs, loss, val_loss):
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'orange', label = 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

def plot_accuracy(epochs, acc, val_acc):
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'orange', label = 'Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
# Cargar el historial desde el archivo
with open('histories/history_densenet_reg.pickle', 'rb') as file:
    saved_history = pickle.load(file)

acc = saved_history['accuracy']
val_acc = saved_history['val_accuracy']
loss = saved_history['loss']
val_loss = saved_history['val_loss']

# %%
plot_loss(range(1, len(loss) + 1), loss, val_loss)
plot_accuracy(range(1, len(loss) + 1), acc, val_acc)

# %%
# CELDA DE PREDICCION - EJECUTAR CON EL MODELO SIN GUARDAR
base_path = '../dataset_sin_borrar_completo/real-vs-fake/'

image_gen1 = ImageDataGenerator(rescale=1./255.,
                               rotation_range=20,
                               horizontal_flip=True)
test_flow = image_gen1.flow_from_directory(
    base_path + 'test/',
    target_size=(224, 224), 
    batch_size=1,
    shuffle = False,
    class_mode='binary'
)
y_pred = model.predict(test_flow)
y_test = test_flow.classes
# Out:
# Found 20000 images belonging to 2 classes.
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20000/20000 ━━━━━━━━━━━━━━━━━━━━ 1798s 90ms/step

# %%
#Metrica de precision
print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
print("AP Score:", metrics.average_precision_score(y_test, y_pred))
print()
print(metrics.classification_report(y_test, y_pred > 0.5))
# Out:
# ROC AUC Score: 0.9889103249999999
# AP Score: 0.9878596085865988
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     10000
#            1       0.97      0.89      0.93     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.94      0.93      0.93     20000
# weighted avg       0.94      0.93      0.93     20000

# %% [markdown]
# # Short EDA - Exploratory Data Results

# %%
# Función para predecir una imagen
def predict_image(img_path, inference_func):
    img = image.load_img(img_path, target_size=(224, 224)) #Normalizacion de los pixeles de la foto
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) 
    img_array /= 255.
    output = inference_func(tf.constant(img_array))
    prediction_value = output["output_0"].numpy()[0][0] #Obtencion del resultado de la funcion de inferencia
    return prediction_value

# %%
true_labels = []
predictions = []
num_images = 3000

# Obtener una muestra aleatoria de imágenes de cada conjunto de datos
selected_real_images = random.sample(real_images, min(num_images, len(real_images)))
selected_fake_images = random.sample(fake_images, min(num_images, len(fake_images)))

# %%
# Procesar las imágenes reales seleccionadas
for img_path in selected_real_images:
    true_labels.append(1)  # Etiqueta 1 para imágenes reales
    prediction_value = predict_image(img_path, inference_func)
    predictions.append(prediction_value)

# Procesar las imágenes falsas seleccionadas
for img_path in selected_fake_images:
    true_labels.append(0)  # Etiqueta 0 para imágenes falsas
    prediction_value = predict_image(img_path, inference_func)
    predictions.append(prediction_value)

# %% [markdown]
# # ROC Curve

# %%
# Calcular la curva ROC
fpr, tpr, _ = roc_curve(true_labels, predictions)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Precision Recall Curve

# %%
# Calcular la precisión y la exhaustividad
precision, recall, _ = precision_recall_curve(true_labels, predictions)

# Calcular el área bajo la curva de precisión-exhaustividad (AP)
average_precision = auc(recall, precision)

# Graficar la curva de precisión-exhaustividad
plt.figure()
plt.plot(recall, precision, color='darkorange', lw=2, label=f'Precision-Recall curve (AP = {average_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # Test Images

# %%
def show_inference(img_path, inference_func):
    img = image.load_img(img_path, target_size=(224, 224))  # Normalización de los píxeles de la foto
    img_array = image.img_to_array(img)
    img_array = tf.image.rgb_to_grayscale(img_array)  # Convertir a escala de grises si es necesario
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array.astype('float32') / 255.0  # Asegurarse de que sea de tipo float y normalizar
    output = inference_func(tf.constant(img_array))
    prediction_value = output["output_0"].numpy()[0][0]  # Obtención del resultado de la función de inferencia
    
    perc = round(prediction_value * 100, 2)
    if prediction_value > 0.5:
        label = "Real" 
    else:
        label = "Fake"
    return perc, prediction_value, label, img

img_path_real = '../dataset/real-vs-fake/test/real'
real_images = os.listdir(img_path_real)
selected_real_images = random.sample(real_images, 2)

img_path_fake = '../dataset/real-vs-fake/test/fake'
fake_images = os.listdir(img_path_fake)
selected_fake_images = random.sample(fake_images, 2)


fig, axes = plt.subplots(1, 4, figsize=(20, 5)) 

for i, img_path in enumerate(selected_real_images):
    perc, _, label, img = show_inference(os.path.join(img_path_real, img_path), inference_func)
    ax = axes[i]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f'Label: {label}\nReal Image Patterns: {perc}%')

for i, img_path in enumerate(selected_fake_images):
    perc, _, label, img = show_inference(os.path.join(img_path_fake, img_path), inference_func)
    ax = axes[i+2]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f'Label: {label}\nReal Image Patterns: {perc}%')

plt.tight_layout()
plt.show()
