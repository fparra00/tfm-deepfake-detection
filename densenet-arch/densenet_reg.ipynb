# %%
#---------- IMPORTS -----------

#Simple Imports
import cv2
import os
import pickle
import numpy as np
import tensorflow as tf
import random
import datetime
import glob
import seaborn as sns

#Tensorflow/Keras Imports
import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam

#Aux Imports
import matplotlib.pyplot as plt
from IPython.display import  display
import pandas as pd
from sklearn import metrics
import tensorflow as tf
from tqdm import tqdm
from sklearn.metrics import confusion_matrix,roc_curve, auc, precision_recall_curve

# %% [markdown]
# ## Model Creator

# %%
#Creacion del modelo preentrenado en CNN

def build_model(pretrained):
    #Sequential - Las capas internas se apilan de manera vertical
    model = Sequential([
        #Pretrained - La construccion del modelo es preentrenado
        pretrained,
        #GlobalAveragePooling2D - Las capas se comunicaran de manera binaria
        layers.GlobalAveragePooling2D(),
        #sigmoid - La salida será binaria
        layers.Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        #binary_crossentropy - Mas adecuado para la clasificacion binaria
        loss='binary_crossentropy',
        #Adam - Version avanzada de SGD
        optimizer=Adam(),
        #accuracy - Metrica a tener en cuenta
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# # Model Generator

# %%
#Ruta de nuestro dataset
base_path = '../dataset/real-vs-fake/'
real_path = '../dataset/real-vs-fake/test/real'
fake_path = '../dataset/real-vs-fake/test/fake'

#Conjuntos de Imagenes
real_images = [os.path.join(real_path, img) for img in os.listdir(real_path)]
fake_images = [os.path.join(fake_path, img) for img in os.listdir(fake_path)]

# %%
#Pick de fotos de entreno

#Normalizamos los valores de los pixeles, dividimos /255 para obtener los valores de RGB entre 0 y 1
image_gen = ImageDataGenerator(rescale=1./255.)

train_flow = image_gen.flow_from_directory(
    base_path + 'train/',
    #Redimension de las imagenes
    target_size=(224, 224),
    #Tamaño de lote
    batch_size=64,
    #Modo de clasificacion, 1 y 0
    class_mode='binary'
)

print("Train subfolders: ", os.listdir(base_path + 'train/'))
# Out:
# Found 50000 images belonging to 2 classes.
# Train subfolders:  ['fake', 'real']

# %%
#Pick de fotos de validacion
image_gen1 = ImageDataGenerator(rescale=1./255.)

valid_flow = image_gen1.flow_from_directory(
    base_path + 'valid/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)

print("Train subfolders: ", os.listdir(base_path + 'valid/'))
# Out:
# Found 5000 images belonging to 2 classes.
# Train subfolders:  ['fake', 'real']

# %% [markdown]
# # Short EDA - Exploratory Data Analysis

# %%
images_df = {
    "folder":[],
    "image_path":[],
    "label":[]
}

for folder in os.listdir(base_path): 
    for label in os.listdir(base_path + "/" + folder):
        for img in glob.glob(base_path + "/" + folder + "/" + label + "/*.jpg"):
            images_df["folder"].append(folder)
            images_df["image_path"].append(img)
            images_df["label"].append(label)

# %%
images_df = pd.DataFrame(images_df)

# %%
images_df
# Out:
#       folder                                         image_path label
# 0       test  ../dataset/real-vs-fake//test/fake\QS994V4M2T.jpg  fake
# 1       test  ../dataset/real-vs-fake//test/fake\QSB3LIBHML.jpg  fake
# 2       test  ../dataset/real-vs-fake//test/fake\QSE7B3Z850.jpg  fake
# 3       test  ../dataset/real-vs-fake//test/fake\QSFUPGKK87.jpg  fake
# 4       test  ../dataset/real-vs-fake//test/fake\QSIGUG4X1W.jpg  fake
# ...      ...                                                ...   ...
# 59995  valid      ../dataset/real-vs-fake//valid/real\69960.jpg  real
# 59996  valid      ../dataset/real-vs-fake//valid/real\69963.jpg  real
# 59997  valid      ../dataset/real-vs-fake//valid/real\69987.jpg  real
# 59998  valid      ../dataset/real-vs-fake//valid/real\69996.jpg  real
# 59999  valid      ../dataset/real-vs-fake//valid/real\69997.jpg  real
#
# [60000 rows x 3 columns]

# %% [markdown]
# ### Labels Distribution

# %%
real_grouped_df = images_df[images_df['label'] == "real"].groupby('folder')
fake_grouped_df = images_df[images_df['label'] == "fake"].groupby('folder')

# %%
real_grouped_df.size()
# Out:
# folder
# test      2500
# train    25000
# valid     2500
# dtype: int64

# %%
fake_grouped_df.size()
# Out:
# folder
# test      2500
# train    25000
# valid     2500
# dtype: int64

# %%
def plot_images(img, label):
    plt.figure(figsize=[12, 12])
    for i in range(16):
        plt.subplot(4, 4, i+1)
        plt.imshow(img[i])
        plt.axis('off')
        if label[i] == 0:
            plt.title("Fake")
        else:
            plt.title("Real")

# %%
img,lbl = next(train_flow)
plot_images(img,lbl)

# %%
for img, label in train_flow:
    print("Values: ", img[0])
    print("Label: ", label[0])
    break
# Out:
# Values:  [[[0.5686275  0.31764707 0.21960786]
#   [0.58431375 0.33333334 0.23529413]
#   [0.59607846 0.34509805 0.2392157 ]
#   ...
#   [0.2784314  0.15294118 0.10196079]
#   [0.28627452 0.15294118 0.10588236]
#   [0.28235295 0.14901961 0.10196079]]
#
#  [[0.5764706  0.3254902  0.227451  ]
#   [0.5921569  0.34117648 0.24313727]
#   [0.6039216  0.3529412  0.24705884]
#   ...
#   [0.28627452 0.16078432 0.10980393]
#   [0.2901961  0.15686275 0.10980393]
#   [0.2901961  0.15686275 0.10980393]]
#
#  [[0.5803922  0.32941177 0.23137257]
#   [0.59607846 0.34509805 0.24705884]
#   [0.60784316 0.35686275 0.2509804 ]
#   ...
#   [0.29803923 0.16470589 0.11764707]
#   [0.30980393 0.16862746 0.1137255 ]
#   [0.3137255  0.17254902 0.11764707]]
#
#  ...
#
#  [[0.54509807 0.4431373  0.454902  ]
#   [0.54901963 0.44705886 0.45882356]
#   [0.54509807 0.43921572 0.45882356]
#   ...
#   [0.46274513 0.3529412  0.27058825]
#   [0.45882356 0.3372549  0.26666668]
#   [0.38431376 0.25490198 0.18823531]]
#
#  [[0.54901963 0.44705886 0.45882356]
#   [0.54901963 0.44705886 0.45882356]
#   [0.54509807 0.43921572 0.45882356]
#   ...
#   [0.41960788 0.3137255  0.24705884]
#   [0.46274513 0.33333334 0.26666668]
#   [0.34117648 0.20000002 0.13725491]]
#
#  [[0.5568628  0.454902   0.4666667 ]
#   [0.5529412  0.45098042 0.46274513]
#   [0.54901963 0.4431373  0.46274513]
#   ...
#   [0.35686275 0.2509804  0.18431373]
#   [0.38431376 0.25490198 0.19607845]
#   [0.45098042 0.30980393 0.24705884]]]
# Label:  1.0

# %%
for img, label in train_flow:
    print(img.shape)
    print(label.shape)
    break
# Out:
# (64, 224, 224, 3)
# (64,)

# %% [markdown]
# # Train Model DenseNet

# %%
#Creacion de modelo DenseNet121

#Modelo preentrenado de 121 capas
densenet = DenseNet121(
    #No utilizamos pesos
    weights=None,
    #No utilizamos fully_connected
    include_top=False,
    #Forma de entrada de las imagenes
    input_shape=(224,224,3)
)
#Construccion de modelo secuencial e impresion de informacion
model = build_model(densenet)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)        │ ?                      │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,037,504 (26.85 MB)
#  Trainable params: 6,953,856 (26.53 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
#Entrenamos el Modelo

#Dividimos las entradas por el numero de batch
train_steps = 100000//64
valid_steps = 20000//64

#Guardamos el historico
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


history = model.fit(
    train_flow,
    epochs = 10,
    steps_per_epoch =train_steps,
    validation_data =valid_flow,
    validation_steps = valid_steps,
    callbacks=[tensorboard_callback]
)

with open('history.pickle', 'wb') as file:
    pickle.dump(history.history, file)
# Out:
# Epoch 1/10
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  782/1562 ━━━━━━━━━━━━━━━━━━━━ 2:36:56 12s/step - accuracy: 0.6042 - loss: 0.6705
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 9710s 6s/step - accuracy: 0.6261 - loss: 0.6486 - val_accuracy: 0.5476 - val_loss: 1.2767
# Epoch 2/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8748s 6s/step - accuracy: 0.7527 - loss: 0.5093 - val_accuracy: 0.6020 - val_loss: 1.0245
# Epoch 3/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8473s 5s/step - accuracy: 0.8187 - loss: 0.4012 - val_accuracy: 0.5844 - val_loss: 1.0543
# Epoch 4/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8342s 5s/step - accuracy: 0.8697 - loss: 0.3047 - val_accuracy: 0.8316 - val_loss: 0.4099
# Epoch 5/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8389s 5s/step - accuracy: 0.9103 - loss: 0.2243 - val_accuracy: 0.7596 - val_loss: 0.6969
# Epoch 6/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8492s 5s/step - accuracy: 0.9335 - loss: 0.1687 - val_accuracy: 0.7758 - val_loss: 0.6322
# Epoch 7/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8687s 6s/step - accuracy: 0.9504 - loss: 0.1258 - val_accuracy: 0.9012 - val_loss: 0.2462
# Epoch 8/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8629s 6s/step - accuracy: 0.9626 - loss: 0.0970 - val_accuracy: 0.9074 - val_loss: 0.2370
# Epoch 9/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8541s 5s/step - accuracy: 0.9709 - loss: 0.0767 - val_accuracy: 0.8616 - val_loss: 0.4394
# Epoch 10/10
# 1562/1562 ━━━━━━━━━━━━━━━━━━━━ 8613s 6s/step - accuracy: 0.9770 - loss: 0.0604 - val_accuracy: 0.9318 - val_loss: 0.2001

# %% [markdown]
# # Evaluation

# %%
#Guardamos el modelo
tf.saved_model.save(model, '../models/densent-arch')
# Out:
# INFO:tensorflow:Assets written to: ../models/densent-arch\assets
# INFO:tensorflow:Assets written to: ../models/densent-arch\assets

# %%
#Cargamos el modelo y obtenemos la funcion de inferencia
model_dir = '../models/densent-arch'
model = tf.saved_model.load(model_dir)
inference_func = model.signatures["serving_default"]
print(inference_func)
# Out:
# ConcreteFunction Input Parameters:
#   inputs (KEYWORD_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='inputs')
# Output Type:
#   Dict[['output_0', TensorSpec(shape=(None, 1), dtype=tf.float32, name='output_0')]]
# Captures:
#   2352895660928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977375328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977375152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895660576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895660400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895660224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895659872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895659696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895659520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895659168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977372512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977372336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895658112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895657056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977369696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977369520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895656000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894967504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894967328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894967152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894966096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977365120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892575088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894964688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894964512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894964336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894964160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892575264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894963104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895368480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895368304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894962048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894961872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894961696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894961520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894961344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894961168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895365664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895365488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894959056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895362848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895362672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894957824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894958176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894957648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894957472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894957296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894957120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895671488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895671312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894954656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894954480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894954304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894954128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895668320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895668144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895671136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894953072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895665504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895665328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979951312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979951136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895665152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894952016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894951840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979950080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895664096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979949024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979948320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895663040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979948848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979948672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895662688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895662512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895666032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895665856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895662336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895665680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895661104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979946032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979945856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979945680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979945504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979945328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894965040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894964864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979945152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894960112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894956240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894955712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979944096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894951664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352894951488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979942864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979948144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979947968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979942688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979942512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979942336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979943216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979939168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769498656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769498480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979941456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979939696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979939344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979940048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769486512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769486336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979939872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979939520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937450336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937450160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979938640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979937056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979936000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979935824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979935648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979935472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352979935296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769498832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937438016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769498304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937437488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937437312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937437136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769497072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769496016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769495840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937436080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937435904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769495664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769495488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769495312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937435376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937435200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769495136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977378848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769494080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977378672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977378496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977378320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977378144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769493024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769492848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769492672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769492496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769492320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769492144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977375680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977375504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769490384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769491792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769489856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769489152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769489504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977374448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769489328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769486160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977373392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977372864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977372688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769488096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977372160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769487040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769486688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937440832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977370048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977369872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977369344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977369168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977368464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769485104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977367056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769484048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769483872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769483696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769483520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769483344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769483168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977365824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769482992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352769482816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937451216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977365472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977365296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937451040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937450864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937450688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977364064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937450512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937437664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937449104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352892574384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895368128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937448048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895367600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937447872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937447696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937447520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937447344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937447168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895366192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937435552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895365312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895365136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937446112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895364784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937445056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895363376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895362496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895362320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937444000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937443824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895362144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937443648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937443472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937443296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895361264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895672016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937443120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895671840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895671664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937442064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977377440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895670080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895669024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895668848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937441008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977376384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937440656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895668672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937440480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937440304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937440128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895667440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352977375856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352937439776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895368832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2352895368656: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
def plot_loss(epochs, loss, val_loss):
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'orange', label = 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

def plot_accuracy(epochs, acc, val_acc):
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'orange', label = 'Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
# Cargar el historial desde el archivo
with open('histories/history_densenet_reg.pickle', 'rb') as file:
    saved_history = pickle.load(file)

acc = saved_history['accuracy']
val_acc = saved_history['val_accuracy']
loss = saved_history['loss']
val_loss = saved_history['val_loss']

# %%
plot_loss(range(1, len(loss) + 1), loss, val_loss)
plot_accuracy(range(1, len(loss) + 1), acc, val_acc)

# %%
# CELDA DE PREDICCION - EJECUTAR CON EL MODELO SIN GUARDAR
base_path = '../dataset_sin_borrar_completo/real-vs-fake/'
image_gen = ImageDataGenerator(rescale=1./255.)
test_flow = image_gen1.flow_from_directory(
    base_path + 'test/',
    target_size=(224, 224), 
    batch_size=1,
    shuffle = False,
    class_mode='binary'
)
y_pred = model.predict(test_flow)
y_test = test_flow.classes
# Out:
# Found 20000 images belonging to 2 classes.
# c:\Users\whysxpvrrv\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20000/20000 ━━━━━━━━━━━━━━━━━━━━ 1798s 90ms/step

# %%
#Metrica de precision
print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
print("AP Score:", metrics.average_precision_score(y_test, y_pred))
print()
print(metrics.classification_report(y_test, y_pred > 0.5))
# Out:
# ROC AUC Score: 0.9889103249999999
# AP Score: 0.9878596085865988
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     10000
#            1       0.97      0.89      0.93     10000
#
#     accuracy                           0.93     20000
#    macro avg       0.94      0.93      0.93     20000
# weighted avg       0.94      0.93      0.93     20000

# %% [markdown]
# # Short EDA - Exploratory Data Results

# %%
# Función para predecir una imagen
def predict_image(img_path, inference_func):
    img = image.load_img(img_path, target_size=(224, 224)) #Normalizacion de los pixeles de la foto
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) 
    img_array /= 255.
    output = inference_func(tf.constant(img_array))
    prediction_value = output["output_0"].numpy()[0][0] #Obtencion del resultado de la funcion de inferencia
    return prediction_value

# %% [markdown]
# ## Confusion Matrix

# %%
# Redondea las predicciones a 0 o 1 usando un umbral de 0.5
y_pred_rounded = (y_pred > 0.5).astype(int)

# Crear la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_rounded)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.title("Confusion Matrix")
plt.show()

# %%
true_labels = []
predictions = []
num_images = 1000

# Obtener una muestra aleatoria de imágenes de cada conjunto de datos
selected_real_images = random.sample(real_images, min(num_images, len(real_images)))
selected_fake_images = random.sample(fake_images, min(num_images, len(fake_images)))

# %%
# Procesar las imágenes reales seleccionadas
for img_path in selected_real_images:
    true_labels.append(1)  # Etiqueta 1 para imágenes reales
    prediction_value = predict_image(img_path, inference_func)
    predictions.append(prediction_value)

# Procesar las imágenes falsas seleccionadas
for img_path in selected_fake_images:
    true_labels.append(0)  # Etiqueta 0 para imágenes falsas
    prediction_value = predict_image(img_path, inference_func)
    predictions.append(prediction_value)

# %% [markdown]
# # ROC Curve

# %%
# Calcular la curva ROC
fpr, tpr, _ = roc_curve(true_labels, predictions)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Precision Recall Curve

# %%
# Calcular la precisión y la exhaustividad
precision, recall, _ = precision_recall_curve(true_labels, predictions)

# Calcular el área bajo la curva de precisión-exhaustividad (AP)
average_precision = auc(recall, precision)

# Graficar la curva de precisión-exhaustividad
plt.figure()
plt.plot(recall, precision, color='darkorange', lw=2, label=f'Precision-Recall curve (AP = {average_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# # Test Images

# %%
def show_inference(img_path, inference_func):
    img = image.load_img(img_path, target_size=(224, 224)) #Normalizacion de los pixeles de la foto
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) 
    img_array /= 255.
    output = inference_func(tf.constant(img_array))
    prediction_value = output["output_0"].numpy()[0][0] #Obtencion del resultado de la funcion de inferencia
    perc = round(prediction_value * 100, 2)
    if prediction_value > 0.5:
        label = "Real" 
    else:
        label = "Fake"
    return perc, prediction_value, label, img

img_path_real = '../dataset/real-vs-fake/test/real'
real_images = os.listdir(img_path_real)
selected_real_images = random.sample(real_images, 2)

img_path_fake = '../dataset/real-vs-fake/test/fake'
fake_images = os.listdir(img_path_fake)
selected_fake_images = random.sample(fake_images, 2)


fig, axes = plt.subplots(1, 4, figsize=(20, 5)) 

for i, img_path in enumerate(selected_real_images):
    perc, _, label, img = show_inference(os.path.join(img_path_real, img_path), inference_func)
    ax = axes[i]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f'Label: {label}\nReal Image Patterns: {perc}%')

for i, img_path in enumerate(selected_fake_images):
    perc, _, label, img = show_inference(os.path.join(img_path_fake, img_path), inference_func)
    ax = axes[i+2]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f'Label: {label}\nReal Image Patterns: {perc}%')

plt.tight_layout()
plt.show()
